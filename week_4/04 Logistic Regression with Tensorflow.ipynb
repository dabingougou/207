# %% [markdown]
# # Assignment 4

# %% [markdown]
# ### <span style="color:chocolate"> Submission requirements </span>
#
# Your work will not be graded if your notebook doesn't include output. In other words, <span style="color:red"> make sure to rerun your notebook before submitting to Gradescope </span> (Note: if you are using Google Colab: go to Edit > Notebook Settings  and uncheck Omit code cell output when saving this notebook, otherwise the output is not printed).
#
# Additional points may be deducted if these requirements are not met:
#
#
# * Comment your code;
# * Each graph should have a title, labels for each axis, and (if needed) a legend. Each graph should be understandable on its own;
# * Try and minimize the use of the global namespace (meaning, keep things inside functions).
# ---

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns  # for nicer plots
sns.set(style="darkgrid")  # default style

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow import keras
from keras import metrics
from keras.datasets import fashion_mnist

tf.get_logger().setLevel('INFO')
# Out:
# 2025-02-09 20:24:25.803506: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-09 20:24:25.808499: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-09 20:24:25.823980: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739132665.843380   18718 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739132665.849731   18718 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-09 20:24:25.872327: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ---
# ### Step 1: Data ingestion

# %% [markdown]
# You'll train a binary classifier using the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset. This consists of 70,000 grayscale images (28x28). Each image is associated with 1 of 10 classes. The dataset was split by the creators; there are 60,000 training images and 10,000 test images. Note also that Tensorflow includes a growing [library of datasets](https://www.tensorflow.org/datasets/catalog/overview) and makes it easy to load them in numpy arrays.

# %%
# Load the Fashion MNIST dataset.
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()

# %% [markdown]
# ---
# ### Step 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# Exploratory Data Analysis (EDA) and Data Preprocessing are often iterative processes that involve going back and forth to refine and improve the quality of data analysis and preparation. However, the specific order can vary depending on the project's requirements. In some cases, starting with EDA, as you see in this assignment, could be more useful, but there is no rigid rule dictating the sequence in all situations.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 1:</span> Getting to know your data (5 points)

# %% [markdown]
# Complete the following tasks:
#
# 1. Print the shapes and types of (X_train, Y_train) and (X_test, Y_test). Interpret the shapes (i.e., what do the numbers represent?). Hint: For types use the <span style="color:chocolate">type()</span> function.
# 2. Define a list of strings of class names corresponding to each class in (Y_train, Y_test). Call this list label_names. Hint: Refer to the Fashion MNIST documentation.

# %%
# YOUR CODE HERE

# Print shapes 
print(50*'*')
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)

print("X_train type:", type(X_train))
print("Y_train type:", type(Y_train))
#print("uint8 means unsigned integer 8-bit (0-255).")


print(50*'*')
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)

print("X_test type:", type(X_test))
print("Y_test type:", type(Y_test))
print(50*'*')

# Define a list of strings for class names
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Please see markdown cell below for comments and answers.
# Out:
# **************************************************
# X_train shape: (60000, 28, 28)
# Y_train shape: (60000,)
# X_train type: <class 'numpy.ndarray'>
# Y_train type: <class 'numpy.ndarray'>
# **************************************************
# X_test shape: (10000, 28, 28)
# Y_test shape: (10000,)
# X_test type: <class 'numpy.ndarray'>
# Y_test type: <class 'numpy.ndarray'>
# **************************************************

# %% [markdown]
# #### Ex 1 Answers
#  - Shape (60000, 28, 28) means that there are 60,000 images, each image is 28 by 28. So first dim is image, the second is row of the image, and the third the column of the image.
#  - Shape (10000, 28, 28) has the exact same interpretation except there are 10,000 data points for the test dataset.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 2:</span> Getting to know your data - cont'd (5 points)

# %% [markdown]
# Fashion MNIST images have one of 10 possible labels (shown above).

# %% [markdown]
# Complete the following tasks:
#
# 1. Display the first 5 images in X_train for each class in Y_train, arranged in a 10x5 grid. Use the label_names list defined above;
# 2. Determine the minimum and maximum pixel values for images in the X_train dataset.

# %%
# YOUR CODE HERE

# Instead of using the code chunk from documentation directly, I tried the object-oriented plotting here

# Get the number of labels
labels_num = np.unique(Y_train)

# Create a empty dict whose key-value pairs are label-[first five index list]
first_five_indices = {label:[] for label in np.unique(Y_train)}

# Loop through Y_train to fill in the dict
for idx, label in enumerate(Y_train):
    if len(first_five_indices[label]) < 5:
        first_five_indices[label].append(idx)
    if all(len(indices) == 5 for indices in first_five_indices.values()):
        break

# first_five_indices

# Plot the first five images for each label
fig, ax = plt.subplots(10, 5,
                       figsize=(20, 20))

for label in labels_num:
#   set col_num to 0 for the start of each INNER loop 
    col_num = 0
    ax[label, 0].set_ylabel(label_names[label],
                            fontsize=20)
    for idx in first_five_indices[label]:
        ax[label, col_num].imshow(X_train[idx,:,:])
#                                      fontsize=12)
        ax[label, col_num].set_xticks([])
        ax[label, col_num].set_yticks([])

        col_num += 1

fig.suptitle("First 5 Images for Each Label",
             fontsize=25)
# Out:
# Text(0.5, 0.98, 'First 5 Images for Each Label')

# %%
# Min and max pixel values for X_Train
print(f"The max pixel value (for ALL images): {np.max(X_train)}")

print(f"The max pixel value (for ALL images): {np.min(X_train)}")
# Out:
# The max pixel value (for ALL images): 255
# The max pixel value (for ALL images): 0

# %% [markdown]
# ---
# ### Step 3: Data preprocessing

# %% [markdown]
# This step is essential for preparing this image data in a format that is suitable for ML algorithms.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 3:</span> Feature preprocessing (5 points)

# %% [markdown]
# In the previous lab, the input data had just a few features. Here, we treat **every pixel value as a separate feature**, so each input example has 28x28 (784) features!

# %% [markdown]
# In this exercise, you'll perform the following tasks:
#
# 1. Normalize the pixel values in both X_train and X_test data so they range between 0 and 1;
# 2. For each image in X_train and X_test, flatten the 2-D 28x28 pixel array to a 1-D array of size 784. Hint: use the <span style="color:chocolate">reshape()</span> method available in NumPy. Note that by doing so you will overwrite the original arrays;
# 3. Pint the shape of X_train and X_test arrays.

# %%
# YOUR CODE HERE

# Task 1: Normalization
a = np.max(X_train, axis=0)

X_train = X_train / 255
X_test = X_test / 255

# Task 2: Flatten X_train and X_test
# use '-1' to deduce shape/flatten
X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)

# Task 3Print out shapes
print("Flattend, and Scaled, X_train_scaled_flattened shape:", X_train.shape)
print("Flattend, and Scaled, X_test_scaled_flattened shape:", X_test.shape)
# Out:
# Flattend, and Scaled, X_train_scaled_flattened shape: (60000, 784)
# Flattend, and Scaled, X_test_scaled_flattened shape: (10000, 784)

# %% [markdown]
# ### <span style="color:chocolate">Exercise 4:</span> Label preprocessing (5 points)

# %% [markdown]
# This assignment involves binary classification. Specifically, the objective is to predict whether an image belongs to the sneaker class (class 7) or not.
#
# Therefore, write code so that for each example in (Y_train, Y_test), the outcome variable is represented as follows:
# * $y=1$, for sneaker class (positive examples), and
# * $y=0$, for non-sneaker class (negative examples).
#
# Note: To avoid "ValueError: assignment destination is read-only", first create a copy of the (Y_train, Y_test) data and call the resulting arrays (Y_train, Y_test). Then overwrite the (Y_train, Y_test) arrays to create binary outcomes.

# %%
# Make copies of the original dataset for binary classification task.
Y_train = np.copy(Y_train)
Y_test = np.copy(Y_test)


# YOUR CODE HERE

# Note that we have to assin 0's first. The other order would not work.
# For Y_train re-labeling
Y_train[Y_train != 7] = 0
Y_train[Y_train == 7] = 1

# For Y_test re-labeling
Y_test[Y_test != 7] = 0
Y_test[Y_test == 7] = 1

# %% [markdown]
# ### <span style="color:chocolate">Exercise 5:</span> Data splits (10 points)

# %% [markdown]
# Using the <span style="color:chocolate">train_test_split()</span> method available in scikit-learn:
# 1. Retain 20% from the training data for validation purposes. Set random state to 1234. All the other arguments of the method are set to default values. Name the resulting dataframes as follows: X_train_mini, X_val, Y_train_mini, Y_val.
# 2. Print the shape of each array.

# %%
# YOUR CODE HERE

np.random.seed(1234)

# Task 1: Split the data for BOTH X and Y 
X_train_mini, X_val, Y_train_mini, Y_val = train_test_split(X_train, Y_train, test_size=0.2)

# Task 2: Print shapes
print("X_train_mini shape:", X_train_mini.shape)
print("X_val shape:", X_val.shape)
print(50*'*')
print("Y_train_mini shape:", Y_train_mini.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train_mini shape: (48000, 784)
# X_val shape: (12000, 784)
# **************************************************
# Y_train_mini shape: (48000,)
# Y_val shape: (12000,)

# %%
# This block is commented out but useful to confirm/explain later why loss is the same for the baseline predictor for both train and val

#print(f"Share of 1 in training data: {Y_train_mini.sum() / len(Y_train_mini)}")
#print(f"Share of 1 in validation data: {Y_train_mini.sum() / len(Y_train_mini)}")

# %% [markdown]
# ### <span style="color:chocolate">Exercise 6:</span> Data shuffling (10 points)

# %% [markdown]
# Since you'll be using Batch Gradient Descent (BGD) for training, it is important that **each batch is a random sample of the data** so that the gradient computed is representative.
#
# 1. Use integer array indexing to re-order (X_train_mini, Y_train_mini) using a list of shuffled indices. In doing so, you will overwrite the arrays.

# %%
np.random.seed(0)
# YOUR CODE HERE

# Create and shuffle the index
# First get the indices
indices = np.arange(0, X_train_mini.shape[0])

# Then shuffle the indices
shuffled_indices = np.random.permutation(indices)

# Shuffle the data
X_train_mini[:] = X_train_mini[shuffled_indices]
Y_train_mini[:] = Y_train_mini[shuffled_indices]

# %% [markdown]
# ---
# ### Step 4: Exploratory Data Analysis (EDA) - cont'd

# %% [markdown]
# Before delving into model training, let's further explore the raw feature values by comparing sneaker and non-sneaker training images.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 7:</span> Pixel distributions (10 points)

# %% [markdown]
# 1. Identify all sneaker images in X_train_mini and calculate the mean pixel value for each sneaker image. Visualize these pixel values using a histogram. Print the mean pixel value across all sneaker images.
# 2. Identify all non-sneaker images in X_train_mini and calculate the mean pixel value for each non-sneaker image. Visualize these pixel values using a histogram. Print the mean pixel value across all non-sneaker images.
# 3. Based on the histogram results, assess whether there is any evidence suggesting that pixel values can be utilized to distinguish between sneaker and non-sneaker images. Justify your response.
#
# Notes: Make sure to provide a descriptive title and axis labels for each histogran. Make sure you utilize Y_train_mini to locate the sneaker and non-sneaker class.

# %%
# YOUR CODE HERE


# Get the mean FOR EACH IMAGE
X_train_mean_pixel_norm = np.mean(X_train_mini, axis=1)

# Using labels to get the mean for EACH IMAGE for each type
sneaker_mean_norm_pixel = X_train_mean_pixel_norm[Y_train_mini == 1]
other_mean_norm_pixel = X_train_mean_pixel_norm[Y_train_mini == 0]

# Calculate the overal mean for EACH TYPE
sneaker_overall_mean = np.mean(sneaker_mean_norm_pixel)
other_overall_mean = np.mean(other_mean_norm_pixel)

# Plot
fig, ax = plt.subplots(1, 2,
                       figsize=(18, 6))

ax[0].hist(sneaker_mean_norm_pixel)
ax[1].hist(other_mean_norm_pixel)

ax[0].axvline(sneaker_overall_mean,
              color='red',
              label=f'Mean Pixel Value: {sneaker_overall_mean:.2f}')
ax[1].axvline(other_overall_mean,
              color='purple',
              label=f'Mean Pixel Value: {other_overall_mean:.2f}')


ax[0].set_xlabel("(Sneakers) Mean Scaled Pixel Value for Each Image")
ax[0].set_ylabel("Frequency",
                 fontsize=18)

ax[1].set_xlabel("(Non-Sneakers) Mean Scaled Pixel Value for Each Image")

ax[0].set_title("Distribution of (Scaled) Pixel Values for Sneakers")
ax[1].set_title("Distribution of (Scaled) Pixel Values for Non-Sneakers")

ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')

plt.show()
print(50*'*')
print("Overall Mean Pixel (Scaled) for Sneakers:", sneaker_overall_mean)
print("Overall Mean Pixel (Scaled) for Non-Sneakers:", other_overall_mean)

# Please see the markdown cell below for comments and answers on if mean pixel is a useful variable for prediction.
# Out:
# **************************************************
# Overall Mean Pixel (Scaled) for Sneakers: 0.1682747275993731
# Overall Mean Pixel (Scaled) for Non-Sneakers: 0.2990019268123916

# %% [markdown]
# #### Ex 7 Answer:
#
# Based on the distribution of pixel values, average pixel value (of each image) **can be, to some extent, utilized** to predict whether or not an image is of a sneaker.
#
#  - First, the mean pixel of all sneaker images is 0.17, while the mean pixel for all non-sneakers is 0.3.
#  - Also, the distribution of pixel among non-sneaker images is more spred-out than that of the sneaker images.
#
#  For example, an image of average pixel 0.5 is more likely to come from the distribution of non-sneaker images that from that of the sneaker images. Hence the usefulness of the average pixel values in prediction.

# %% [markdown]
# ---
# ### Step 4: Modeling

# %% [markdown]
# ### <span style="color:chocolate">Exercise 8:</span> Baseline model (10 points)

# %% [markdown]
# When dealing with classification problems, a simple baseline is to select the *majority* class (the most common label in the training set) and use it as the prediction for all inputs.
#
# With this information in mind:
#
# 1. What is the number of sneaker images in Y_train_mini?
# 2. What is the number of non-sneaker images in Y_train_mini?
# 3. What is the majority class in Y_train_mini?
# 4. What is the accuracy of a majority class classifier for Y_train_mini?
# 5. Implement a function that computes the Log Loss (binary cross-entropy) metric and use it to evaluate this baseline on both the mini train (Y_train_mini) and validation (Y_val) data. Use 0.1 as the predicted probability for your baseline (reflecting what we know about the original distribution of classes in the mini training data). Hint: for additional help, see the file ``04 Logistic Regression with Tensorflow_helpers.ipynb``.

# %%
# YOUR CODE HERE



# 1. Number of sneaker images:
print("Number of sneakers in Y_train_mini:", Y_train_mini.sum())

# 2. Number of non-sneaker images:
print("Number of non-sneakers in Y_train_mini:", len(Y_train_mini) - Y_train_mini.sum())

# 3. The majority is non-sneaker

# 4. Calculate accuracy for the baseline predictor
# Define a baseline predictor
base_y_hat = 0.1

# Accurary 
print(f"Accuracy: ({432} + {0}) / {432 + 48 + 0 + 0} = 0.9" )

# 5. Implement log-loss function
def log_loss(labels, prediction):
    """  
    Returns the log loss 
    Args:
        labels: 1-D array
        prediction: scaler (in which case will be broadcasted) or 1-D array of the same length as labels
    """
    return - np.sum((1 / labels.shape[0]) * (labels * np.log(prediction) + (1 - labels) * np.log(1 - prediction)))

# Print out the log-loss
print(f"Log loss for the constant predictor: {log_loss(Y_train_mini, base_y_hat)}")
# Out:
# Number of sneakers in Y_train_mini: 4800
# Number of non-sneakers in Y_train_mini: 43200
# Accuracy: (432 + 0) / 480 = 0.9
# Log loss for the constant predictor: 0.3250829733914482

# %% [markdown]
# ### <span style="color:chocolate">Exercise 9:</span> Improvement over Baseline with TensorFlow (10 points)

# %% [markdown]
# Let's use TensorFlow to train a binary logistic regression model much like you did in the previous assignment. The goal here is to build a ML model to improve over the baseline classifier.
#
# 1. Fill in the <span style="color:green">NotImplemented</span> parts of the build_model() function below by following the instructions provided as comments. Hint: the activation function, the loss, and the evaluation metric are different compared to the linear regression model;
# 2. Build and compile a model using the build_model() function and the (X_train_mini, Y_train_mini) data. Set learning_rate = 0.0001. Call the resulting object *model_tf*.
# 3. Train *model_tf* using the (X_train_mini, Y_train_mini) data. Set num_epochs = 5 and batch_size=32. Pass the (X_val, Y_val) data for validation. Hint: see the documentation behind the [tf.keras.Model.fit()](https://www.tensorflow.org/api_docs/python/tf/keras/Model) method.
# 3. Generate a plot (for the mini training and validation data) with the loss values on the y-axis and the epoch number on the x-axis for visualization. Make sure to include axes name and title. Hint: check what the [tf.keras.Model.fit()](https://www.tensorflow.org/api_docs/python/tf/keras/Model) method returns.

# %%
# My own implementation - to keep
def build_model(num_features, learning_rate):
  """Build a TF linear regression model using Keras.

  Args:
    num_features: The number of input features.
    learning_rate: The desired learning rate for SGD.

  Returns:
    model: A tf.keras model (graph).
  """
  # This is not strictly necessary, but each time you build a model, TF adds
  # new nodes (rather than overwriting), so the colab session can end up
  # storing lots of copies of the graph when you only care about the most
  # recent. Also, as there is some randomness built into training with SGD,
  # setting a random seed ensures that results are the same on each identical
  # training run.
  tf.keras.backend.clear_session()
  tf.random.set_seed(0)

  # Build a model using keras.Sequential. While this is intended for neural
  # networks (which may have multiple layers), we want just a single layer for
  # binary logistic regression.
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(
      units=1,        # output dim - becuase this is a binary (0 - 1) classification
      input_shape=(num_features,),  # input dim
      use_bias=True,               # use a bias (intercept) param
      activation='sigmoid',       # binary logistic transformation
      kernel_initializer='ones',  # initialize params to 1
      bias_initializer='ones',    # initialize bias to 1
  ))

  # We need to choose an optimizer. We'll use SGD, which is actually mini-batch GD
  optimizer = tf.keras.optimizers.SGD(learning_rate)

  # Finally, compile the model. Select the accuracy metric. This finalizes the graph for training.
  # Precision and recall are not asked by this exercise but kept for my own information.
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    
  return model

# %%
tf.random.set_seed(0)
# 2. Build and compile model
# YOUR CODE HERE

# Build and compile
model_tf = build_model(num_features=X_train_mini.shape[1],
                       learning_rate=0.0001)

# 3. Fit the model
# YOUR CODE HERE
# Fit the model with specified hyperparameters
history = model_tf.fit(X_train_mini, Y_train_mini,
             epochs=5,
             batch_size=32,
             validation_data=(X_val, Y_val),
             verbose=1)
# Out:
# Epoch 1/5
# /workspaces/207/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-02-09 20:24:30.509032: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-02-09 20:24:30.613441: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 150528000 exceeds 10% of free system memory.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1017 - loss: 208.5961 - precision: 0.1017 - recall: 1.0000 - val_accuracy: 0.1000 - val_loss: 199.9825 - val_precision: 0.1000 - val_recall: 1.0000
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.1017 - loss: 196.0804 - precision: 0.1017 - recall: 1.0000 - val_accuracy: 0.1000 - val_loss: 187.4252 - val_precision: 0.1000 - val_recall: 1.0000
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1017 - loss: 183.5648 - precision: 0.1017 - recall: 1.0000 - val_accuracy: 0.1000 - val_loss: 174.8679 - val_precision: 0.1000 - val_recall: 1.0000
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.1017 - loss: 171.0492 - precision: 0.1017 - recall: 1.0000 - val_accuracy: 0.1000 - val_loss: 162.3107 - val_precision: 0.1000 - val_recall: 1.0000
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.1017 - loss: 158.5334 - precision: 0.1017 - recall: 1.0000 - val_accuracy: 0.1000 - val_loss: 149.7533 - val_precision: 0.1000 - val_recall: 1.0000

# %%
# Plot loss of the untuned model: monitor train and val losses
fig, ax = plt.subplots(figsize=(12,6))

epochs = range(1, len(history.history['loss']) + 1)

ax.plot(epochs, history.history['loss'],
        label='Training Loss')
ax.plot(epochs, history.history['val_loss'],
        label="Validation Loss")

#plt.ylim(bottom=5.2)

ax.set_xlabel("Epochs")
ax.set_ylabel("Cross-Entropy Loss")
ax.set_title("Training Loss vs Epochs")

plt.xticks(range(1, len(history.history['loss']) + 1, 1)) 
ax.legend(title='learning_rate=0.0001\n', 
          loc=[0.02,0.45])

plt.text(1, 155, 
         "Note: Training loss is ABOVE validation loss, indicating possible undertraining.\n\
          Y axis does not start at 0.",
          fontsize=10, ha='left', color='purple')
plt.show()

# %% [markdown]
# ---
# ### Step 5: Hyperparameter tuning

# %% [markdown]
# Hyperparameter tuning is a crucial step in optimizing ML models. It involves systematically adjusting hyperparameters such as learning rate, number of epochs, and optimizer to find the model configuration that leads to the best generalization performance.
#
# This tuning process is typically conducted by monitoring the model's performance on the validation vs. training set. It's important to note that using the test set for hyperparameter tuning can compromise the integrity of the evaluation process by violating the assumption of "blindness" of the test data.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 10:</span> Hyperparameter tuning (10 points)

# %% [markdown]
# 1. Fine-tune the **learning rate** and **number of epochs** hyperparameters of *model_tf* to determine the setup that yields the most optimal generalization performance. Feel free to explore various values for these hyperparameters. Hint: you can manually test different hyperparameter values or you can use the [Keras Tuner](https://www.tensorflow.org/tutorials/keras/keras_tuner). If you decide to work with the Keras Tuner, define a new model building function named <span style="color:chocolate">build_model_tuner()</span>.
#
# After identifying your preferred model configuration, print the following information:
#
# 2. The first five learned parameters of the model (this should include the bias term);
# 3. The loss at the final epoch on both the mini training and validation datasets;
# 4. The percentage difference between the losses observed on the mini training and validation datasets.
# 5. Compare the training/validation loss of the TensorFlow model (model_tf) with the baseline model's loss. Does the TensorFlow model demonstrate an improvement over the baseline model?
#
#
# Please note that we will consider 'optimal model configuration' any last-epoch training and validation loss that is below 0.08.

# %%
# I frist tune the model using Teras Tuner
# then provide answers and print-outs in the last code cell for this Exercise
# Import the turner API
import keras_tuner as kt

def build_tuned_model(hp, num_features):
    """Builds a Keras model with tunable hyperparameters.
    
    Args:
        hp: Hyperparameter object (used by Keras Tuner. Called in the Search() API).
        num_features: The number of input features.
    
    Returns:
        model: A compiled tf.keras model.
    """
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(
        units=1,  
        input_shape=(num_features,),  # Use num_features dynamically
        use_bias=True,
        activation='sigmoid',
        kernel_initializer='ones',
        bias_initializer='ones',
    ))

    # Tune optimizer
    optimizer_choice = hp.Choice("optimizer", ["SGD", "Adam"])

    # Tune learning rate
    learning_rate = hp.Choice("learning_rate", [1e-4, 1e-3, 1e-2, 1.e-1, 5.e-1])

    # Initialize chosen optimizer
    if optimizer_choice == "SGD":
        optimizer = tf.keras.optimizers.SGD(learning_rate)
    else:
        optimizer = tf.keras.optimizers.Adam(learning_rate)

    # Compile model
    # Precision and recall are not asked by the exercise but kept for my own consumption
    model.compile(optimizer=optimizer, 
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %%
# After re-building the model to be tuned
#   define tuner with Random Search
tuner = kt.RandomSearch(
    lambda hp: build_tuned_model(hp, num_features=X_train_mini.shape[1]),  
    objective="val_loss",  # Optimize for lowest validation cross-entropy loss
    max_trials=20,  
    executions_per_trial=1,
    directory="my_keras_tuner",
    project_name="tune_optimizer_lr_epochs"
)

# Search for optimal hyperprameters
tuner.search(X_train_mini, Y_train_mini, 
             validation_data=(X_val, Y_val),
             epochs=15,  
             batch_size=32,
             verbose=1)
# Out:
# Reloading Tuner from my_keras_tuner/tune_optimizer_lr_epochs/tuner0.json

# %%
# Get the best hyperparameters
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best optimizer: {best_hp.get('optimizer')}")
print(f"Best learning rate: {best_hp.get('learning_rate')}")

# Set epochs 
epochs = 15  

# Train final model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hp)
history = best_model.fit(X_train_mini, Y_train_mini,
                         epochs=epochs,
                         batch_size=32,
                         validation_data=(X_val, Y_val),
                         verbose=1)
# Out:
# Best optimizer: Adam
# Best learning rate: 0.001
# Epoch 1/15
# 2025-02-09 20:24:43.754536: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 150528000 exceeds 10% of free system memory.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.1474 - loss: 135.6546 - precision: 0.1025 - recall: 0.9499 - val_accuracy: 0.9358 - val_loss: 0.1652 - val_precision: 0.7002 - val_recall: 0.6267
# Epoch 2/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9436 - loss: 0.1392 - precision: 0.7256 - recall: 0.7169 - val_accuracy: 0.9588 - val_loss: 0.1042 - val_precision: 0.7845 - val_recall: 0.8100
# Epoch 3/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9617 - loss: 0.0993 - precision: 0.8111 - recall: 0.8135 - val_accuracy: 0.9681 - val_loss: 0.0846 - val_precision: 0.8390 - val_recall: 0.8425
# Epoch 4/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9710 - loss: 0.0819 - precision: 0.8614 - recall: 0.8527 - val_accuracy: 0.9724 - val_loss: 0.0721 - val_precision: 0.8606 - val_recall: 0.8642
# Epoch 5/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9759 - loss: 0.0703 - precision: 0.8881 - recall: 0.8731 - val_accuracy: 0.9757 - val_loss: 0.0634 - val_precision: 0.8740 - val_recall: 0.8842
# Epoch 6/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9785 - loss: 0.0621 - precision: 0.9001 - recall: 0.8872 - val_accuracy: 0.9782 - val_loss: 0.0572 - val_precision: 0.8863 - val_recall: 0.8967
# Epoch 7/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9804 - loss: 0.0565 - precision: 0.9064 - recall: 0.9007 - val_accuracy: 0.9794 - val_loss: 0.0532 - val_precision: 0.8909 - val_recall: 0.9050
# Epoch 8/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9820 - loss: 0.0527 - precision: 0.9122 - recall: 0.9105 - val_accuracy: 0.9804 - val_loss: 0.0508 - val_precision: 0.8939 - val_recall: 0.9125
# Epoch 9/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9827 - loss: 0.0503 - precision: 0.9151 - recall: 0.9152 - val_accuracy: 0.9807 - val_loss: 0.0492 - val_precision: 0.8948 - val_recall: 0.9142
# Epoch 10/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9834 - loss: 0.0486 - precision: 0.9190 - recall: 0.9174 - val_accuracy: 0.9807 - val_loss: 0.0481 - val_precision: 0.8948 - val_recall: 0.9142
# Epoch 11/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9839 - loss: 0.0474 - precision: 0.9213 - recall: 0.9202 - val_accuracy: 0.9813 - val_loss: 0.0474 - val_precision: 0.8980 - val_recall: 0.9175
# Epoch 12/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9842 - loss: 0.0465 - precision: 0.9230 - recall: 0.9218 - val_accuracy: 0.9818 - val_loss: 0.0469 - val_precision: 0.9004 - val_recall: 0.9192
# Epoch 13/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9847 - loss: 0.0458 - precision: 0.9240 - recall: 0.9257 - val_accuracy: 0.9818 - val_loss: 0.0465 - val_precision: 0.9005 - val_recall: 0.9200
# Epoch 14/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9847 - loss: 0.0452 - precision: 0.9234 - recall: 0.9268 - val_accuracy: 0.9822 - val_loss: 0.0462 - val_precision: 0.9021 - val_recall: 0.9217
# Epoch 15/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9848 - loss: 0.0446 - precision: 0.9240 - recall: 0.9269 - val_accuracy: 0.9825 - val_loss: 0.0460 - val_precision: 0.9031 - val_recall: 0.9242

# %%
# This code cell prints out answers to this Exercise

#   2. The first five learned parameters of the model (this should include the bias term);
#   3. The loss at the final epoch on both the mini training and validation datasets;
#   4. The percentage difference between the losses observed on the mini training and validation datasets.
#   5. Compare the training/validation loss of the TensorFlow model (model_tf) with the baseline model's loss. Does the TensorFlow model demonstrate an improvement over the baseline model?

# Task 2: the first five learned parameters
print(f"The first five params: \n{best_model.get_weights()[0][0:5]}")
print(f"The bias term param: {best_model.get_weights()[1]}")


# Task 3: loss at the final epoch
print(50*"*")
print(f"Training loss at last epoch: {history.history['loss'][-1]:.3f}")
print(f"Validation loss at last epoch: {history.history['val_loss'][-1]:.3f}")


# Task 4: percentage different in train and val losses 
print(50*"*")
(history.history['loss'][-1] - history.history['val_loss'][-1]) / history.history['val_loss'][-1]
print(f"Percent diff between train loss and val loss \n- using val loss as denominator: {(history.history['loss'][-1] - history.history['val_loss'][-1]) / history.history['val_loss'][-1]:.2%}")
print('Negative value indicates trian loss smaller')

# Task 5: compare model_tf with baseline model
print(50*'*')
print(f"Baseline training loss: {log_loss(Y_train_mini, base_y_hat):.4f}")
print(f"Baseline validation loss: {log_loss(Y_val, base_y_hat):.4f}")
print("The above two are equal because we did the split before shuffle\n and baseline model is a constant")
print(50*'-')
print("Hence TensorFlow model is a significant improve!")
# Out:
# The first five params:
# [[0.9007316 ]
#  [0.7504129 ]
#  [0.57743335]
#  [0.5648694 ]
#  [0.10873759]]
# The bias term param: [-1.2243388]
# **************************************************
# Training loss at last epoch: 0.044
# Validation loss at last epoch: 0.046
# **************************************************
# Percent diff between train loss and val loss
# - using val loss as denominator: -3.84%
# Negative value indicates trian loss smaller
# **************************************************
# Baseline training loss: 0.3251
# Baseline validation loss: 0.3251
# The above two are equal because we did the split before shuffle
#  and baseline model is a constant
# --------------------------------------------------
# Hence TensorFlow model is a significant improve!

# %% [markdown]
# ---
# ### Step 6: Evaluation and Generalization

# %% [markdown]
# Now that you've determined the optimal set of hyperparameters, it's time to evaluate your optimized model on the test data to gauge its performance in real-world scenarios, commonly known as inference.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 11:</span> Computing accuracy (10 points)

# %% [markdown]
# 1. Calculate aggregate accuracy on both mini train and test datasets using a probability threshold of 0.5. Hint: You can utilize the <span style="color:chocolate">model.evaluate()</span> method provided by tf.keras. Note: Aggregate accuracy measures the overall correctness of the model across all classes in the dataset;
#
# 2. Does the model demonstrate strong aggregate generalization capabilities? Provide an explanation based on your accuracy observations.

# %%
# YOUR CODE HERE

# Calculate accuracy. 
# Note that precision and recall are not asked, but I am printing them out for my own.
# According to the Teras doc, default threashold is 0.5
train_loss, train_accuracy, train_precision, train_recall = best_model.evaluate(X_train_mini, Y_train_mini, verbose=1)
test_loss, test_accuracy, test_precision, test_recall = best_model.evaluate(X_test, Y_test, verbose=1)

print(f"Accuracy on training data: {train_accuracy:.3f}")
print(f"Accuracy on test data: {test_accuracy:.3f}")
# Out:
#  165/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 922us/step - accuracy: 0.9892 - loss: 0.0341 - precision: 0.9394 - recall: 0.9452
# 2025-02-09 20:25:22.271626: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 150528000 exceeds 10% of free system memory.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 940us/step - accuracy: 0.9851 - loss: 0.0422 - precision: 0.9237 - recall: 0.9274
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9812 - loss: 0.0478 - precision: 0.8962 - recall: 0.9177
# Accuracy on training data: 0.985
# Accuracy on test data: 0.981

# %% [markdown]
# #### Ex 11 Answer
#
#  - Recall that baseline model (predicting constant 0.9) has an accuracy of 0.9.
#  - In comparison, **accuracy of the trained model on training is 0.985**, a substantial improvement from the base line model.
#  - **Accuracy of the trained model on test is 0.981**, only slightly smaller than that on the training data.
#
#  Hence, the trained model demonstrates a strong aggregate generalization capability.

# %% [markdown]
# ### <span style="color:chocolate">Exercise 12:</span> Fairness evaluation (10 points)

# %% [markdown]
# 1. Generate and visualize the confusion matrix on the test dataset using a probability threshold of 0.5. Additionally, print the True Positives (TP), False Negatives (FN), False Positives (FP), and True Negatives (TN). Hint: you can utilize the <span style="color:chocolate">model.predict()</span> method available in tf.keras, and then the <span style="color:chocolate">confusion_matrix()</span>, <span style="color:chocolate">ConfusionMatrixDisplay()</span> methods available in sklearn.metrics;
#
# 2. Compute subgroup accuracy, separately for the sneaker and non-sneaker classes, on the test dataset using a probability threshold of 0.5. Reflect on any observed accuracy differences (potential lack of fairness) between the two classes.
#
# 3. Does the model demonstrate strong subgroup generalization capabilities? Provide an explanation based on your accuracy observations.

# %%
# YOUR CODE HERE

# Task 1: Confusion matrix (visualization in the next code cells)
Y_test_predicted_probabilities = best_model.predict(X_test)

# Generate label using the threshold of 0.5
Y_test_predicted_probabilities[Y_test_predicted_probabilities > 0.5] = 1
Y_test_predicted_probabilities[Y_test_predicted_probabilities <= 0.5] = 0 

# Convert labels to integers
Y_test_pred = Y_test_predicted_probabilities.astype(int)
np.unique(Y_test_pred)

# Calculate the confusion matrix
conf_matrix = tf.math.confusion_matrix(
    Y_test,
    Y_test_pred,
    num_classes=None,
    weights=None,
    name=None
)

# Print out the confusion matrix
print("First print out the entire confusion matrix")
print(conf_matrix)

print(50*'*')
print("Predicted snakers:")
print(f"True Positives: {conf_matrix[0][0]}")
print(f"False Positives: {conf_matrix[1][0]}")

print(30*'-')
print("Predicted non-snakers:")
print(f"False Negatives: {conf_matrix[0][1]}")
print(f"True Negatives: {conf_matrix[1][1]}")

# Task 2: Subgroup accuracy
print(50*'*')
print('Subgroup accuracy')
print(f"Sneaker Class Accuracy (Recall): {conf_matrix[0][0] / (conf_matrix[0][0] + conf_matrix[0][1]):.2%}")

print(30*'-')
print(f"Non-Sneaker Class Accuracy: {conf_matrix[1][1] / (conf_matrix[1][0] + conf_matrix[1][1]):.2%}")

# Task
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# First print out the entire confusion matrix
# tf.Tensor(
# [[8889  111]
#  [  77  923]], shape=(2, 2), dtype=int32)
# **************************************************
# Predicted snakers:
# True Positives: 8889
# False Positives: 77
# ------------------------------
# Predicted non-snakers:
# False Negatives: 111
# True Negatives: 923
# **************************************************
# Subgroup accuracy
# Sneaker Class Accuracy (Recall): 98.77%
# ------------------------------
# Non-Sneaker Class Accuracy: 92.30%

# %%
# Visualization
# Convert the matrix entries to numpy arrays so that the ConfusionMatrixDisplay() would work
conf_matrix_np = conf_matrix.numpy() if isinstance(conf_matrix, tf.Tensor) else np.array(conf_matrix)


disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_np, display_labels=["Sneaker", "Non-Sneaker"])
#disp.plot(cmap="Blues")  # Customize color scheme

fig, ax = plt.subplots(figsize=(6, 4))

ax.set_ylabel("Predicted Label")

disp.plot(cmap="Blues", ax=ax)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### Ex 12 Comments and Answers
#  - For subgroups, accuary for sneaker class (TP recall) is 98.77%
#  - Accuracy for non-sneaker class (TF recall) is 92.3%.
#  - Based on this observation, the model prediction is not fair in the sense it performs better for sneaker class. However, it should be noted that the accuracy for non-sneaker class is reasonablly good (92.3%).
#
#  ##### Note on assumption and definition
#  I carried out what is asked by the exercise based on the following assumption/definition
#
#  - Accuracy for snaker class:
#  $$
# accuracy_{sneaker} = \frac{TP}{TP + FN}
#  $$
#
#  - Accuracy for non-snaker class:
#  $$
# accuracy_{non-sneaker} = \frac{TN}{FP + TN}
#  $$

# %% [markdown]
# ----
# #### <span style="color:chocolate">Additional practice question</span> (not graded)

# %% [markdown]
# Is it possible to enhance the prediction accuracy for the sneaker class by performing the following steps?
#
# 1. Implement data balancing techniques, such as oversampling or undersampling, to equalize the representation of both classes.
# 2. After balancing the data, retrain the model on the balanced dataset.
# 3. Evaluate the model's performance, particularly focusing on the accuracy achieved for the sneaker class.
